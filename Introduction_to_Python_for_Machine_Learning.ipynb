# %% [markdown]
# <a href="https://colab.research.google.com/github/lems01/Hamoye/blob/main/Introduction_to_Python_for_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = '/FoodBalanceSheets_E_Africa_NOFLAG.csv'

df = pd.read_csv(url, encoding='latin-1')

# %%
df.shape
# Out:
# (60943, 12)

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
# Get the unique countries in the dataset
df['Area'].nunique()
# Out:
# 49

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age','Nationality','Overall']

# %%
test = pd.DataFrame(lst, columns = col, index = [i for i in range(1, 4)])

# %%
test .head()
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
df['Y2017'].describe()
# Out:
# count     59437.000000
# mean        140.917765
# std        1671.862359
# min       -1582.000000
# 25%           0.000000
# 50%           0.100000
# 75%           9.000000
# max      190873.000000
# Name: Y2017, dtype: float64

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.groupby('Element').df[['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018]].count()
# Out:
#   File "<ipython-input-35-3cb965f3fd22>", line 1
#     df.groupby('Element').df[['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018]].count()
#                                                                   ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df.groupby('Element')['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'].count()
# Out:
# <ipython-input-40-70f621197b87>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Element')['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'].count()
#                                         Y2014  Y2015  Y2016  Y2017  Y2018
# Element
# Domestic supply quantity                 5244   5245   5250   5258   5256
# Export Quantity                          3660   3704   3653   3660   3646
# Fat supply quantity (g/capita/day)       4965   4974   4980   4982   4987
# Feed                                     1216   1177   1215   1213   1225
# Food                                     4896   4901   4910   4912   4913
# Food supply (kcal/capita/day)            4947   4955   4963   4965   4969
# Food supply quantity (kg/capita/yr)      4860   4865   4874   4876   4877
# Import Quantity                          4919   4911   4908   4929   4945
# ...

# %%
df.groupby('Element')['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'].sum()
# Out:
# <ipython-input-41-52edf1381155>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Element')['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'].sum()
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# ...

# %%
df['Y2014'].isnull().sum()/len(df)
# Out:
# 0.026073544131401474

# %%
df.corr()
# Out:
# <ipython-input-47-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# ...

# %%
df.groupby(['Element', 'Area'])['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'].sum()
# Out:
# <ipython-input-52-b61f5e1bdb59>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Element', 'Area'])['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'].sum()
#                                                    Y2014     Y2015     Y2016  \
# Element                  Area
# Domestic supply quantity Algeria                83755.94  85972.86  87157.61
#                          Angola                 53786.91  55482.91  55719.68
#                          Benin                  29864.06  27661.67  30650.03
#                          Botswana                2670.84   2916.14   2921.83
#                          Burkina Faso           24637.15  23658.17  24498.86
# ...                                                  ...       ...       ...
# Tourist consumption      Cabo Verde                 3.00      5.00      7.00
#                          Egypt                    348.00    286.00     23.00
# ...

# %%
df_sup = df[df["Area"] == 'Madagascar']
df_sup.head()
# Out:
#    Area Code        Area  Item Code         Item  Element Code  \
# 0          4  Madagascar       2501   Population           511
# 1          4  Madagascar       2501   Population          5301
# 2          4  Madagascar       2901  Grand Total           664
# 3          4  Madagascar       2901  Grand Total           674
# 4          4  Madagascar       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# ...

# %%
df_sup.groupby(['Element', 'Area'])['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'].sum()
# Out:
# <ipython-input-91-ed1c920ca298>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_sup.groupby(['Element', 'Area'])['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'].sum()
#                                                         Y2014       Y2015  \
# Element                                Area
# Domestic supply quantity               Madagascar  1996716.35  2021493.55
# Export Quantity                        Madagascar   150020.64   157614.47
# Fat supply quantity (g/capita/day)     Madagascar    10225.56    10235.74
# Feed                                   Madagascar   216927.89   225050.22
# Food                                   Madagascar  1212332.49  1232361.10
# Food supply (kcal/capita/day)          Madagascar   454257.00   453383.00
# Food supply quantity (kg/capita/yr)    Madagascar    49650.63    49345.13
# Import Quantity                        Madagascar   274144.48   267018.46
# ...

# %%
df.groupby('Area')['Y2017'].sum().sort_values()
# Out:
# Area
# Sudan (former)                       0.00
# Ethiopia PDR                         0.00
# Comoros                             59.84
# Seychelles                         442.34
# Sao Tome and Principe            12662.63
# Cabo Verde                       14650.74
# Guinea-Bissau                    19102.77
# Lesotho                          21267.96
# Botswana                         22101.30
# Djibouti                         22729.91
# Gambia                           23154.18
# Gabon                            27979.64
# Liberia                          29342.20
# Namibia                          29874.89
# Central African Republic         29937.00
# Congo                            41181.68
# Togo                             49841.88
# Mauritius                        51114.83
# Eswatini                         54343.33
# Sierra Leone                     55311.33
# Chad                             71594.68
# Rwanda                           73663.69
# ...

# %%
array  = ([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

# %%
array[:1]
# Out:
# [[94, 89, 63]]

# %%
S = [['him', 'sell'], [90, 28, 43]]

# %%
S[0][1][1]
# Out:
# 'e'

# %%
df.groupby('Item')['Y2015','Y2018'].sum()
# Out:
# <ipython-input-83-8a9970b4dbf0>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Item')['Y2015','Y2018'].sum()
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %%
my_tuppy = (1,2,5,8)

# %%
my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-e0cfa6830280> in <cell line: 1>()
# ----> 1 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
df.groupby('Area')['Y2017'].sum().sort_values()
# Out:
# Area
# Sudan (former)                       0.00
# Ethiopia PDR                         0.00
# Comoros                             59.84
# Seychelles                         442.34
# Sao Tome and Principe            12662.63
# Cabo Verde                       14650.74
# Guinea-Bissau                    19102.77
# Lesotho                          21267.96
# Botswana                         22101.30
# Djibouti                         22729.91
# Gambia                           23154.18
# Gabon                            27979.64
# Liberia                          29342.20
# Namibia                          29874.89
# Central African Republic         29937.00
# Congo                            41181.68
# Togo                             49841.88
# Mauritius                        51114.83
# Eswatini                         54343.33
# Sierra Leone                     55311.33
# Chad                             71594.68
# Rwanda                           73663.69
# ...

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]

# %%
x = y[1][1]

# %%
x
# Out:
# 8
